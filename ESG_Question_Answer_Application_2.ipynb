# %% [markdown]
# ### Question Answer Application
# The goal of Question Answering is to find the answer to a question given a question and an accompanying context. The predicted answer will be either a span of text from the context or an empty string (indicating the question cannot be answered from the context).

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.7-py3-none-any.whl (249 kB)
#      |████████████████████████████████| 249 kB 37.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.21.6)
# Collecting streamlit
#   Downloading streamlit-1.12.0-py2.py3-none-any.whl (9.1 MB)
#      |████████████████████████████████| 9.1 MB 51.8 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.3.5)
# Collecting wandb>=0.10.32
#   Downloading wandb-0.13.1-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 48.5 MB/s
# Collecting tokenizers
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 57.8 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 62.1 MB/s
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.8.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.1 MB/s
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 68.4 MB/s
# Collecting transformers>=4.6.0
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 57.8 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (3.8.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 12.4 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (4.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 44.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers>=4.6.0->simpletransformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=4.6.0->simpletransformers) (3.0.9)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.17.3)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.3)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 24.8 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (7.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (5.4.8)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 66.4 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (57.4.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.3 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2.10)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 72.2 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 67.7 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 77.9 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 76.1 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 18.9 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 73.3 MB/s
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 26.0 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (3.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (6.0.1)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.3.5.1)
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 65.4 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 57.6 MB/s
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (2.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (0.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.6.0->simpletransformers) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2022.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->simpletransformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (7.1.2)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 74.0 MB/s
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 10.7 MB/s
# Collecting rich>=10.11.0
#   Downloading rich-12.5.1-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 72.0 MB/s
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: semver in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (2.13.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.5.1)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.4)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Collecting watchdog
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 8.5 MB/s
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (5.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: ipykernel>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (7.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (6.1.12)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (7.9.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 53.4 MB/s
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.0.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.5)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 2.3 MB/s
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.13.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.11.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (23.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.5.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.16.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.47.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (3.4.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (3.2.0)
# Building wheels for collected packages: pathtools, seqeval, validators
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=cc61e1a1cb0e26c29a3e685f0c86694cb9d67ce11e1f443bacc3e036e4a8a313
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=aa97d87877f99e5e802ad1f139716df4c56dec3b9b7cc7c0cb1798a0a01b2a35
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=74a2884970862228ce6b66963661a7bee2fe070137d613dae4d62b150ea9ff9e
#   Stored in directory: /root/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built pathtools seqeval validators
# Installing collected packages: jedi, urllib3, smmap, pyyaml, gitdb, fsspec, commonmark, xxhash, watchdog, validators, tokenizers, shortuuid, setproctitle, sentry-sdk, rich, responses, pympler, pydeck, pathtools, multiprocess, huggingface-hub, GitPython, docker-pycreds, blinker, wandb, transformers, streamlit, seqeval, sentencepiece, datasets, simpletransformers
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed GitPython-3.1.27 blinker-1.5 commonmark-0.9.1 datasets-2.4.0 docker-pycreds-0.4.0 fsspec-2022.7.1 gitdb-4.0.9 huggingface-hub-0.8.1 jedi-0.18.1 multiprocess-0.70.13 pathtools-0.1.2 pydeck-0.7.1 pympler-1.0.1 pyyaml-6.0 responses-0.18.0 rich-12.5.1 sentencepiece-0.1.97 sentry-sdk-1.9.0 seqeval-1.2.2 setproctitle-1.3.2 shortuuid-1.0.9 simpletransformers-0.63.7 smmap-5.0.0 streamlit-1.12.0 tokenizers-0.12.1 transformers-4.21.1 urllib3-1.25.11 validators-0.20.0 wandb-0.13.1 watchdog-2.1.9 xxhash-3.0.0

# %%
import json
import random

def split_data(data):
    """
    Split the data in 80:20 ratio
    """
    random.shuffle(data)
    split_index = int(len(data) * 0.85)
    return data[:split_index], data[split_index:]

def main():
    """
    Main function
    """
    with open('/content/answers_v2.json') as f:
        data = json.load(f)['data']

    train_data, test_data = split_data(data)

    with open('/content/train.json', 'w') as f:
        json.dump({'data': train_data}, f)

    with open('/content/test.json', 'w') as f:
        json.dump({'data': test_data}, f)

main()

# %%
import json
with open(r"train.json", "r") as read_file:
    train = json.load(read_file)['data']

# %%
train_squad = []
for item in train:
    for paragraph in item['paragraphs']:
        context = paragraph['context']
        qas = []
        for qa in paragraph['qas']:
            question = qa['question']
            id = qa['id']
            answers = []
            for answer in qa['answers']:
                text = answer['text']
                answer_start = answer['answer_start']
                answers.append({'text': text, 'answer_start': answer_start})
            is_impossible = qa['is_impossible']
            qas.append({'question': question, 'id': id, 'answers': answers, 'is_impossible': is_impossible})
        train_squad.append({'context': context, 'qas': qas})

# %%
train_squad
# Out:
# [{'context': 'Target focused on manufacturing and R&D operations.  2017  Emissions - 66, 609 Metric tonnes.  23% reduction compared to 2020 goals of 20% reduction.   ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': '23% reduction', 'answer_start': 95}],
#     'is_impossible': False}]},
#  {'context': 'We made efforts to reduce emissions by introducing highly-efficient facilities, etc. However, due to a large increase in production volume, the emission amount was lower than our target. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'introducing highly-efficient facilities',
#       'answer_start': 39}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce emissions by introducing highly-efficient facilities, etc',
#       'answer_start': 19}],
#     'is_impossible': False}]},
#  {'context': 'Our new GHG emission reduction targets from 01 July 2017 includes a 24% reduction in Scope 1 and 2 GHG emissions by 2025 and 35% by 2030 against  2015 baseline. ANZâ€™s total global Scope 1 and 2 target has been submitted to the Science Based Target Initiative (SBTi) for informal review. The SBTi confirmed that the target can be considered science-based.  Our 2017 scope 1 and 2 emissions were 180767 tCO2-e, equivalent to a 13.6% emission reduction from the 2015 base year emissions, meaning we are more than a third of the way towards reaching our target (13.6/35 = 39%). This reduction was driven primarily through our digital transformation program and flexible work practices, which combined to enable consolidation of our property portfolio and shift transactional services on-line. We have proactively worked on both the installation of improved plant equipment and operational work practices. Examples include optimisation of data centres, more energy efficient design, engineering and physical configuration as well as increased flexible work practices enabling the strategic consolidation of our commercial portfolio.  ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'optimisation of data centres, more energy efficient design, engineering and physical configuration',
#       'answer_start': 920}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'a 24% reduction in Scope 1 and 2 GHG emissions by 2025 and 35% by 2030 against  2015 baseline',
#       'answer_start': 66}],
#     'is_impossible': False}]},
#  {'context': 'In FY2015, AGL committed in its Greenhouse Gas Policy to close all conventional coal power stations by 2050.  Our approach to transitioning to a low-carbon future is set out within AGLâ€™s Greenhouse Gas Policy (GHG Policy). Our GHG Policy acknowledges that Australia is moving to a carbon-constrained future, and provides a framework within which we will structure our greenhouse gas reduction activities. It also presents a pathway for the gradual decarbonisation of our generation portfolio by 2050. The GHG Policy states that we will: * continue to provide the market with safe, reliable, affordable and sustainable energy options * not build, finance or acquire new conventional coal fired power stations in Australia (i.e. without carbon capture and storage) * not extend the operating life of any of our existing coal fired power stations * close, by 2050, all existing coal fired power stations in our portfolio * improve the greenhouse gas efficiency of our operations, and those over which we have influence * continue to invest in new renewable and near-zero emission technologies * make available innovative and cost-effective solutions for our customers, such as distributed renewable generation, battery storage, and demand management solutions * incorporate a forecast of future carbon pricing into all generation capital expenditure decisions, and * continue to be an advocate for effective long-term government policy to reduce Australiaâ€™s emissions in a manner that is consistent with the long-term interests of  consumers and investors. Climate change is recognised by our stakeholders as an important issue for our business. We are working with our investors, customers, employees, communities in which we operate, the broader community, and governments, to clearly articulate the strategic steps we are taking to reduce emissions and transition to a carbon constrained future. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'close all conventional coal power stations by 2050',
#       'answer_start': 57}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'transitioning to a low-carbon future',
#       'answer_start': 126}],
#     'is_impossible': False}]},
#  {'context': 'In 2017 we set a target to reduce our global gross Scope 1 and 2 emissions by 25%. So far we have made good progress and will meet this target when our Frankfurt office switches over to a renewable tariff in 2018.   This is currently an interim target as we are looking at the options of setting longer term targets as an ongoing priority. This is a challenge however due to  the  small number of people we employ, limited offices we operate and relatively low energy consumption.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'renewable tariff', 'answer_start': 188}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce our global gross Scope 1 and 2 emissions by 25%',
#       'answer_start': 27}],
#     'is_impossible': False}]},
#  {'context': 'AIG is a supporter of the UK Carbon Reduction Commitment in the UK, and has committed to reducing the Carbon emissions associated with its UK business operations by 20% by the year 2020.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reducing the Carbon emissions', 'answer_start': 89}],
#     'is_impossible': False}]},
#  {'context': 'Since Astellas founded on 2005, Astellas has collected the environmental performances such like energy usage of all business facilities global basis, and as of 2015, the capture ratio of energy data is 100%. Our data accuracy has been assessed by external auditor, KPMG group, based on ISAE3000 and ISAE3410 standard.  Astellas has submitted this target which is described on the "SBTi Target Submission Form" to the Science Based Targets initiatves on early August 2018.  Astellas has the original climate-related medium-term target for reducing GHGs in its Environmental Action Plan (EAP). The former climate-related EAP (expired on the end of  2017) covered all activities in Japan and manufacturing plants outside Japan, the coverage ratio against all Astellas activities was approximately 80%. Since Astellas has already captured the performance data of all business sites with the limited assurance by KPMG according to ISAE3000 and ISAE3410 standards, Astellas has expand the current EAPâ€™s boundary to cover 100% of Scope1 and Scope2 emissions.  The current EAP has been applied internally since 2018. The climate-related EAP was created with consultation service from Japanese Ministry of the Environment to apply the SBT requirement by referring the SDA tools. Astellas has planned to submit our SBT draft to SBT initiatives by the end of March 2019. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'Science Based Targets initiatves',
#       'answer_start': 417}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reducing GHGs in its Environmental Action Plan (EAP)',
#       'answer_start': 538}],
#     'is_impossible': False}]},
#  {'context': "This target hasn't been submitted to SBTI yet. The target is linked to a monetary reward in the French branch of the toll Road business. It entails an overall emissions reduction of a 1.5% for that subsidirary in three years that covers scopes 1 and 2. Currently, the percentage of emissions achieved is 0 as scope 1+2  emissions increased from 2015 to 2017 in France. This is due to the increase in scope, mainly as a result of the inclusion of refrigerant gases in the scope that makes the overall scope 1+2 emissions increase.Therefore. despite the several efficiency measures implemented, and despite the decrease in scope 2 emissions, scope 1 emissions increased from  2016 to 2017.  ",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'SBTI', 'answer_start': 37}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'emissions reduction of a 1.5% for that subsidirary in three years that covers scopes 1 and 2',
#       'answer_start': 159}],
#     'is_impossible': False}]},
#  {'context': 'Our energy-efficiency target for 2030 is a 30% reduction in our absolute energy intensity against our 2016 performance, while our long term GHG emissions target is a net 30% reduction in emissions against the 2016 level. The long term stretch targets align with our aspiration to develop a carbon-neutral mine. Building on the outcomes of the FutureSmart Miningâ„¢ Innovation Open Forum on energy that we held in December 2016, we held an energy efficiency workshop in October 2017 to further assist in identifying and prioritising opportunities, and in developing action plans meet our longer term targets. By 2020, we will have completed technical reviews to identify the priority energy and carbon-reduction options at our major operations. A science-based target currently requires the inclusion of scope 3. An appropriate methodology for the mining industry is being developed. Although not verified, our target meets the scope 1 and 2 requirements of a science-based target. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'A science-based target', 'answer_start': 744}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'a 30% reduction in our absolute energy intensity against our 2016 performance',
#       'answer_start': 41}],
#     'is_impossible': False}]},
#  {'context': "The GHG emissions absolute target set refers to Autostrade per lâ€™Italia (ASPI), the leading toll motorway builder and operator in Italy and the main concessionaire company within Atlantia group, with about 61% of the group's network under concession. Considering the base year (2015) a 6% emissions decrease consists in a reduction of about 4800 GHG tons in absolute terms. The absolute reduction target set is strictly related to the base line year boundary in terms of technological equipment and extension of the highway network and will not take into account any additional emission attributable to new equipment and roadworks on the actual infrastructure.",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': '6% emissions decrease consists in a reduction of about 4800 GHG tons in absolute terms',
#       'answer_start': 288}],
#     'is_impossible': False}]},
#  {'context': 'We have increased our Transport CO2 from 18,813 Tons in 2009 to 21,491 Tons in 2017 = This is because of increased KM due to Increased Parcel & Pallet Volumes and re structuring of our delivery network throughout the whole country. In 2018 we have introduced our first Electric Vans x 10 & Trikes x10 in Dublin coupled with Eco Driver Training and Committed to achieving ISO 50001 in our Fleet Transport by year end , Also the replacement of 47 HGV Trucks to Euro 6 by the end of 2018 ( 33 % of our HGV Fleet will be Euro 6 by year end), All remaining trucks are now Euro 5.  In 2016 we purchased 249 LDV Euro 6 Large Vans, 149 Fiat Diablo Euro 6, 350 Ford Connect Euro 6. In 2017 a further 458 Euro6 vehicles were replaced. ( 44 % in our Small Vans are now Euro 6 ) All these actions will help bring reductions in CO2 in Transport Diesel for 2018 and years ahead.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'Electric Vans x 10 & Trikes x10 in Dublin coupled with Eco Driver Training and Committed to achieving ISO 50001',
#       'answer_start': 269}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reductions in CO2 in Transport Diesel',
#       'answer_start': 801}],
#     'is_impossible': False}]},
#  {'context': "Arcadis' global position on targets focuses on a process of continuous improvement within its environmental metrics, similar to that done in our Health & Safety approach (with considerable success). In 2015, the Netherlands achieved its 2012-2015 emissions reduction goals previously set and updated its goals to reflect a longer term vision of continuous improvement (30% reduction compared against its 2010 baseline year). In 2016, Arcadis began assessing whether these rigorous goals aligned with science-based targets which is anticipated to continue into 2018.  To date, the Netherlands achieved its goal (50% reduction compared against its 2010 baseline year).  ",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'science-based targets', 'answer_start': 500}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'improvement within its environmental metrics',
#       'answer_start': 71}],
#     'is_impossible': False}]},
#  {'context': 'Total volume target aims to limit the CO2 emission within domestic boudary where Japan is committed in the Paris accord.  The target is to keep beyond 4.4 million tons of on the average during the FY2012 through FY2020.    ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'limit the CO2 emission within domestic boudary',
#       'answer_start': 28}],
#     'is_impossible': False}]},
#  {'context': 'Target and ongoing emissions  reflect those based on Scope 1 emissions reported through US EPA greenhouse gas Mandatory  Reporting Rule (MRR).  Scope 1 emissions from sources not covered by US EPA MRR (e.g., refrigerants use, SF6,  small engines exempt under MRR, mobile sources) comprise <1 percent of  total reported  greenhouse gas emissions.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'US EPA greenhouse gas Mandatory  Reporting Rule (MRR)',
#       'answer_start': 88}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'Scope 1 emissions', 'answer_start': 53}],
#     'is_impossible': False}]},
#  {'context': "Adobe commits to reduce absolute global scope 1 and 2 emissions 25% by 2025 from 2015 levels.  We have to point out that, Adobe has experienced substantial growth in business since 2015:  in 2017 our business grew 25% (revenues), FTE 14%, while our absolute emissions grew by less than 6%.  Essentially, we are managing our carbon footprint despite major business growth but we anticipate progress on both short- and long-term SBTs in coming years particularly due to our ambitious RE100 goals that do not rely on offsets and instead on true renewable energy additionality.   Also, since we are ONLY using true grid-scale RE as an offset to absolute emissions, our Bangalore solar PPA that launched in August of 2017 gave us only a partial year's emissions -- which did not bring down our total absolute emissions.  We are planning progress on reducing absolute emissions over the next few years as this, and other vPPA, CCE, green tarriffs are in place and up-and-running.",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'true grid-scale RE', 'answer_start': 606}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce absolute global scope 1 and 2 emissions 25% by 2025 from 2015 levels',
#       'answer_start': 17}],
#     'is_impossible': False}]},
#  {'context': 'The reduction in energy consumption, at year 2022, will be reached thanks to several targets to be met: within water sector, Environment sector, and electricity distribution sector. All sectors in fact have specific targets. In particular, -Areti (the Company that distributes electricity): as previous years, various interventions have been carried out in 2017 and are expected before year 2022: i) reduction of physical losses in the distribution network due to change in HV (from 60 kV to 150 kV), MV (from 8.4 kV to 20 kV), LV (from 231 V to 400 V); ii) new transformer installation - MV/LV transformers with very low losses; variation in the MV network configuration.  In all Group areas also LED system lighting will be installed.  These and other measures will bring to a total reduction of 100,000 t of CO2 (in 2022) if compared to 2011 emissions.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'i) reduction of physical losses in the distribution network due to change in HV (from 60 kV to 150 kV), MV (from 8.4 kV to 20 kV), LV (from 231 V to 400 V); ii) new transformer installation - MV/LV transformers with very low losses; variation in the MV network configuration.  In all Group areas also LED system lighting will be installed.',
#       'answer_start': 397}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduction in energy consumption',
#       'answer_start': 4}],
#     'is_impossible': False}]},
#  {'context': "Aptar established target for the reduction of Scopes 1 + 2 emission (market based) by 30% by 2020 compared with a 2016 base year. In this reporting year the Scopes 1 + 2 emission (market based) had reduced by 6.5% compared to that target based year, so, Aptar's target is 22% complete. We achieved a reduction of 8% thanks to the increase of green energy use and electrical energy reduction in our plants where appropriate energy efficiency programs had completed. ",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'increase of green energy use and electrical energy reduction',
#       'answer_start': 330}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduction of Scopes 1 + 2 emission (market based) by 30% by 2020',
#       'answer_start': 33}],
#     'is_impossible': False}]},
#  {'context': 'New Objective:  By FY-30, reduce our net scope 1 & 2 GHG emission by 50% from our 2012 baseline.    Normalized CO2e per 100 pounds of production is reported, in order to allow customer base to determine scope 3 relevance based on purchased quantity.  However, total CO2e will not be disclosed, to preserve sensitive market information (total production). ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'By FY-30, reduce our net scope 1 & 2 GHG emission by 50% from our 2012 baseline',
#       'answer_start': 16}],
#     'is_impossible': False}]},
#  {'context': 'This target has been set using methodology provided by the Sectoral Decarbonization Approach. Altria and its operating companiesâ€™ Scope 1 and Scope 2 GHG emissions for full year 2017 decreased 10.7% compared with 2016. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'Sectoral Decarbonization Approach',
#       'answer_start': 59}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'Scope 1 and Scope 2 GHG emissions',
#       'answer_start': 132}],
#     'is_impossible': False}]},
#  {'context': 'The direct footprint of a.s.r. head office consists of waste, fuel, heat, electricity, cooling, commuter travel and business travel1. In 2017, a.s.r. sought to reduce its direct footprint by 2% compared to 2016. This target is not achieved; the total footprint increased by 0.2%Â². When looking at the emissions per FTE, emissions remained more or less the same compared to 2016.  The scope 1 emissions decreased by 194 tonnes of CO2-equivalent, mainly due to the use of fewer and more economical lease cars and the reduced use of natural gas. However, the scope 3 emissions increased by 210 tonnes of CO2-equivalent. This is due to an increase in commuter traffic in kilometres, with car use increasing proportionally (compared to, for example, public transport use).  With a reduction of 6.8%, the target of achieving a 5% reduction in emissions from the a.s.r. fleet was achieved. As mentioned above, this is due to the use of fewer and more economical lease cars. Translated into kilometres, the reduction of carbon emissions is 21.9% per kilometre.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'use of fewer and more economical lease cars and the reduced use of natural gas',
#       'answer_start': 464}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce its direct footprint by 2% compared to 2016',
#       'answer_start': 160}],
#     'is_impossible': False}]},
#  {'context': "This target will be mainly achieved thanks to a greater use of more flexible CCGT. The evaluation is based on mathematical method, taking into account : electricity production and installed capacity prevision until 2022 (Business Plan 2018-2022), emission factor forecasts, A2A's time series about its emissions. All data has been compared with EU-ETS limits. It is necessary to underline that the base year is an average between 2008-2012. Hence, this target places A2A in line with the EU Directive 2009/29/EC. The Target is not easily achieved because in the following years in particular in 2019 the absolute emission will increase due to the rise in the electricity demand. The  target will be reached  with a sharp decrease of emission from coal based plant that are planned to be turned off in 2025, and a shrink in the exploitation of the heavy oil source (thanks to reconversion of the plant).",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'use of more flexible CCGT', 'answer_start': 56}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'decrease of emission from coal based plant that are planned to be turned off in 2025, and a shrink in the exploitation of the heavy oil source (thanks to reconversion of the plant)',
#       'answer_start': 721}],
#     'is_impossible': False}]},
#  {'context': 'In 2016 AbbVie decided to take a leadership approach to climate change by setting new aggressive targets to reduce emissions.  Our GHG reduction target is to reduce emissions 25% absolute, by 2025 with a 2015 baseline.  All GHG targets are combined scope 1 and 2 market based.  It should be noted that the CO2 emissions associated with the acquisition of Stemcentryx and Pharmacyclics are not included in the target calculation because they were not included in the 2015 baseline.  The CO2 emissions from these two businesses account for less than 1% of the total AbbVie CO2 emissions. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce emissions 25% absolute, by 2025 with a 2015 baseline',
#       'answer_start': 158}],
#     'is_impossible': False}]},
#  {'context': 'The scope of target setting of Asahi carbon zero target setting is only domestic, and the scope of scope 1 + 2 reported this time is domestically and Australia and the scope of application is different.\n In addition, domestic group companies at the base year is the scope of application, and domestic groups that have increased after the basis of reference are being applied.\n Furthermore, since the CO2 emission reduction contribution contribution amount is considered in consideration of the amount of CO2 emission reduction contribution by the green power certificate in Japan, the reporting year performance set by the scope 1 + 2 total value of the reporting year and the carbon zero is different.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'carbon zero', 'answer_start': 37}],
#     'is_impossible': False}]},
#  {'context': 'AMP recognises to ensure global temperature rise is limited to 2C; global emissions should be net zero by 2050. While AMPâ€™s target recognises that AMP needs to decrease its own emissions, it also recognises that, consistent with net zero concept, that it should offset its emissions through supporting the actions of others. AMP is reducing its use of resources and carbon footprint and has set a number of priorities including: â€“ reducing greenhouse gas emissions by 40% in the period 2013â€“2021 â€“ pursuing energy efficiency through lighting upgrades, IT initiatives and more flexible and efficient use of office space â€“ working with contractors, landlords and service providers to increase waste recycling â€“ reducing non-essential air travel and paper consumption â€“ encouraging employee work practices that reduce environmental impacts â€“ encouraging suppliers to reduce the impacts of their products and services â€“ maintaining carbon neutrality â€“ continuing with external assurance of AMPâ€™s carbon footprint. AMP has offset part or all of its operational emissions since 2009. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'pursuing energy efficiency through lighting upgrades, IT initiatives and more flexible and efficient use of office space â€“ working with contractors, landlords and service providers to increase waste recycling â€“ reducing non-essential air travel and paper consumption',
#       'answer_start': 506}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'AMP is reducing its use of resources and carbon footprint',
#       'answer_start': 327}],
#     'is_impossible': False}]},
#  {'context': 'Beginning in 2010, Beckâ€™s signing of the AIA 2030 Commitment set into motion a goal to reduce operational GHG emissions from our main offices, operations, and mobile fleet to be carbon neutral by 2030 and continue to be carbon neutral afterward. Beck continues to prioritize emissions reductions despite significant growth in our business practice. In 2016, we added mobile emissions to be included in our target.  2010 scope 1 and scope 2 emissions were 1966.23 t CO2e; 2017 scope 1 and 2 emissions were 5,385.40  t CO2e.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'a goal to reduce operational GHG emissions from our main offices, operations, and mobile fleet to be carbon neutral by 2030',
#       'answer_start': 79}],
#     'is_impossible': False}]},
#  {'context': 'In Brazil, the scope 2 emissions estimation depends on the Brazilian grid Emission Factor (EF). This EF varies every month, according to the energy type (hydro/wind/solar/coal) dispatched to the grid. Thus, it is not possible to establish any absolute or relative target for scope 2 in tCO2e. In this case, the energy reduction is calculated in MWh and then, the avoided emissions are estimated using the current EF.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'Emission Factor (EF)', 'answer_start': 74}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'scope 2 emissions', 'answer_start': 15}],
#     'is_impossible': False}]},
#  {'context': 'The target will end at the end of the current period, and Acerinox will be able to evaluate if the strategy set has been correct and has reached those target set. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [],
#     'is_impossible': True}]},
#  {'context': 'The goal is to make CO2 emissions zero by 2030, including the ASKLE establishments, distribution centers and subsidiaries.\n November 28, 2017 Joined the "RE100" sponsored by the CLIMATE GROUP.\n The goal of RE100 aims at 100% renewable energy throughout the group including subsidiaries in 2030.\n Askle reduces CO2 emissions by switching power to renewable energy.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'RE100', 'answer_start': 206}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'CO2 emissions zero', 'answer_start': 20}],
#     'is_impossible': False}]},
#  {'context': 'Emissions regarding stationary combustion, after switching to the free energy-buying system The use of generators was significantly reduced.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'use of generators was significantly reduced',
#       'answer_start': 96}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [],
#     'is_impossible': True}]},
#  {'context': 'In order to do our part we have adhered to the Science Based Targets initiative, where we have committed to define greenhouse gas emission reduction targets that are in line with currently available climate scenarios in order to avoid an increase in global temperature above two degrees Celsius. We have taken a first step by defining reduction targets for our direct and indirect (Scope 1 and 2) GHG emissions by 2020, 2030 and 2050 at a corporate level, including our global operations where we have operational control (Colombia, Panama, El Salvador and Guatemala). Said Scope 1 and 2 emissions correspond to approximately 90% of our total Greenhouse Gas Emissions. This Target is not verified by the SBTi and our scope 3 emissions are excluded from the definition of our Science Based Target, since a unified methodology is currently being developed so that financial institutions can develop emissions reduction targets associated with their lending and investment activities, which are the most significant for our industry, at this stage our targets will undergo verification by the SBTi. Our first challenge, to reduce our Scope 1+2 emissions by 10% below 2010 levels in 2020 was achieved in 2017. For this reason we have assumed our new challenge: to reduce our Scope 1+2 emissions by 24% below 2017 levels in 2030, this will move us closer to our final goal of reducing our 2010 GHG levels by 55% in 2050. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'Science Based Targets initiative',
#       'answer_start': 47}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce our Scope 1+2 emissions by 24% below 2017 levels in 2030, this will move us closer to our final goal of reducing our 2010 GHG levels by 55% in 2050',
#       'answer_start': 1260}],
#     'is_impossible': False}]},
#  {'context': 'Our target has a long-term objective of continuous improvement. In this respect, we look at least to 2020 to maintain our objective of not increasing net emissions. This makes it a challenging target since it requires efficiency improvements due to fact that the company is growing at close to two-digit rate in employees and revenues. This is aligned with the 2 degrees objective of the Paris Agreement. In case the target is not achieved through direct improvements, we will offset the rest to meet the target. On top of this, Amadeus invests 16% of its revenues in R&D and this helps airlines and other customers to meet their own scope 1 and 2 targets.  Amadeus maintains a carbon neutral growth policy, with 2015 as the baseline year.  In 2015,  the Amadeus Data Centre implemented a carbon neutral growth policy, offsetting all scope 1 and 2 emissions that exceed the levels reached in 2014. In 2016, this policy was expanded to the rest of the Amadeus Group, so we committed not to exceed scope 1 and 2 emissions reached in 2015.  We have kept scope 1+2 emissions constant in the reporting year. To this end, we have been working with the United Nations Framework Convention on Climate Change to invest in Clean Development Mechanism projects in India. The total carbon offset carried out for 2017 to keep our emissions at the level reached in 2015 was 8,267 tons of CO2. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'Clean Development Mechanism', 'answer_start': 1213}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'not increasing net emissions', 'answer_start': 135}],
#     'is_impossible': False}]},
#  {'context': 'In 2017, we refined the 2020 measures and targets for climate action at ABB replacing an energy intensity target which used $ revenue as the denominator. Going forward, our new target is to reduce our absolute GHG emissions by 40 percent by 2020 vs a 2013 baseline. We made this change because we wanted to clearly demonstrate our commitment, drive action across all of our operations, and show the impacts of our efforts. The reduction includes a methodology change in our vehicle emissions, further information is available in our 2017 Sustainability Report.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'methodology change in our vehicle emissions',
#       'answer_start': 448}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce our absolute GHG emissions by 40 percent by 2020 vs a 2013 baseline',
#       'answer_start': 190}],
#     'is_impossible': False}]},
#  {'context': 'Target of the pharmaceutical plant of Reinbek. The targets are established in annual basis due to the energy management system ISO 50001. The base reference is the forecast consumption for the current year, taking into account production forecast and plant activity. Despite the individual target was not accomplished the global target (the addition of all site targets) has been accomplished with more than 100%.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'energy management system ISO 50001',
#       'answer_start': 102}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [],
#     'is_impossible': True}]},
#  {'context': 'CDP2017 ABS1 applies.\n The target value setting range is Azville Corporation, a domestic consolidated subsidiary and an overseas main production base (Dalian, Thailand).\n ASVIL ASVIL Group has been established in fiscal 2006, which was built in fiscal 2006, and in fiscal 2017-fiscal 2017, we have reduced the total amount reduction target from 43% reduction in fiscal 2019.\n Previously, the original unit goals also managed, but now only more strict total amount goals are managed.\n At regular progress conferences, the transition of units of sales is also reviewed and steadily achieving target values.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [],
#     'is_impossible': True}]},
#  {'context': 'We are pursuing our vision of a CO2-free energy supply of BMW Group and aim to reduce CO2 emissions of all BMW Group locations to zero until 2050. The absolute target Abs1 for the BMW Group production network is a major, joining the RE100 initiative of the Climate Group at the COP21 in Paris and commit to purchase 100 % renewable electricity in the future a further step to achieve the target Abs2 (for details of our renewable energy target within the RE100 initiative please see C4.2). Since Abs1 as well as the renewable energy target in C4.2 are interim targets to achieve Abs2, measures in 2017 are the same as described there.  Procedure: On the way to 100% renewable energy supply of our locations BMW Group takes a holistic approach. Top priority is given to systematic reduction of energy consumption, as energy savings are always the best alternative, both for the environment and for our business. To cover the remaining energy requirements, we are expanding our own renewable energy generation systems and are increasingly drawing power from local renewable sources. The renewable energy target in C4.2  addresses only CO2-emissions from purchased electricity. Abs1 includes also emissions from heat supply as well as from fuel combustion inside the BMW Group. On a mid to long-term perspective we see the potential to replace in an economically reasonable way fossil fuels by renewable fuels (e.g. biogas) and are doing this e.g. in Spartanburg (USA) with landfill gas.   Scope of target: The emissions in Scope include all BMW Group locations including the Joint Venture locations in China. It excludes emissions from company owned vehicles and airplanes. From the 2015 emissions figures we get as percentage of emissions in scope 94%.  Remark: To calculate the % of emissions in scope we included in the denominator emissions from company owned cars and planes since these are BMW Group Scope 1 & Scope 2 emissions. In the method as outlined by the technical paper â€œSECTORAL DECARBONIZATION APPROACH (SDA): A method for setting corporate emission reduction targets in line with climate scienceâ€\x9d of the Science Based Targets Initiative these two categories belong however to other industry sectors. For our own sector, which belongs in the actual methodology to â€œOther Industriesâ€\x9d, the target Abs2 means zero net CO2 emissions which is a science based target. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'joining the RE100 initiative of the Climate Group at the COP21 in Paris and commit to purchase 100 % renewable electricity in the future',
#       'answer_start': 221}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'a CO2-free energy supply of BMW Group and aim to reduce CO2 emissions of all BMW Group locations to zero until 2050',
#       'answer_start': 30}],
#     'is_impossible': False}]},
#  {'context': 'We have taken a public commitment to reach neutrality in 2030, all residual emissions (after emissions curtailment) will be compensated by purchasing carbon credits.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'purchasing carbon credits', 'answer_start': 139}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reach neutrality in 2030', 'answer_start': 37}],
#     'is_impossible': False}]},
#  {'context': 'ACCIONA is a carbon neutral company since 2016 by means of emission reduction and offsetting. This target covers the reduction part of the neutrality.  The target was not achieved due to a rise in 2017 scope 1+2 emissions. The rise in scope 1 emissions has been caused mainly by the rise of Trasmediterranea and ACCIONA Construction activities, while the increase in scope 2 emissions has been triggered by the increase of the desalination activity in water stressed countries, where the access to renewable electricity is very limited.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'scope 1+2 emissions', 'answer_start': 202}],
#     'is_impossible': False}]},
#  {'context': "BBVA has approved its new strategy on climate change and sustainable development.  As part of its commitment to mitigate environmental and social risks and minimize potentially negative direct and indirect impacts, this stratey includes a new emission reduction target  of 68% by 2025, compared to 2015. This target covers 100%  of BBVA's scope 1 and 2 emissions, which include those that come from the direct energy consumption (fossil fuels) and from electricity consumption. More than 80% of the total gross emissions in the base year came from the electricity consumption. This means that the evolution of this indicator will be highly impacted by the use of renewable energy in our buildings. In this sense, BBVA has committed to the RE100 initiative to sourcing 100% renewable power by 2030. On the  hand, BBVA has been the first Spanish bank to commit to the Science Based Targets Initiative. The methodology for assesing financial institutions emissions is still being developed, but we have committed to setting and validating the SBT within two years  from the date at which an applicable methodology becomes available.",
#   'qas': [{'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': "a new emission reduction target  of 68% by 2025, compared to 2015. This target covers 100%  of BBVA's scope 1 and 2 emissions",
#       'answer_start': 237}],
#     'is_impossible': False}]},
#  {'context': 'Australia Post set the performance reduction target in 2010 and revised the baseline in 2014 following the acquisition of the StarTrack business which had a material impact on the emissions of the group. In 2010 emissions peaked at 360,599 tonnes and by 30 June 2017 we had reduced the total to 279,737 tonnes. This is a 19.7% reduction against our target (80% of the target) and a 22.4% reduction against our 2010 peak. There are significant cost and energy savings with this  transformation, working out at $10 million (AUD) each year from an electricity perspective. The reduction in fuel usage represents total annual savings of around $1 million.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'reduction in fuel usage', 'answer_start': 574}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'a 19.7% reduction against our target (80% of the target) and a 22.4% reduction against our 2010 peak',
#       'answer_start': 319}],
#     'is_impossible': False}]},
#  {'context': 'This is a new, absolute target for Accenture: Accenture commits to reduce scope 1 and 2 emissions by 55% by 2025, from a fiscal 2016 baseline. This target includes 100% of scope 1 and 2 emissions. This target is in line with the recommendations from the Paris Agreement and produces an average year-on-year emissions reduction of more than 8%.  To achieve our target, we are implementing ambitious initiatives, which include amplifying our deployment of renewable energy in 11 focus countries representing 90% of energy consumption. We are also transitioning half of the Accenture-owned car fleet to electric vehicles. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'deployment of renewable energy in 11 focus countries representing 90% of energy consumption. We are also transitioning half of the Accenture-owned car fleet to electric vehicles',
#       'answer_start': 440}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce scope 1 and 2 emissions by 55% by 2025',
#       'answer_start': 67}],
#     'is_impossible': False}]},
#  {'context': "In 2014, ALTEN had set up an absolute target on its transportation related emissions. This target applies for the vehicle fleet in France. Although an action plan was implemented to reach the target, GHG reduction efforts were counterbalanced by the significant growth in ALTEN's activity. Therefore, absolute emissions in the target's perimeter have increased in absolute terms between 2013 and 2017.",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
# ...
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'targeting a 3% absolute reduction in Scope 1 and Scope 2 emissions each year for a total 15% reduction by 2020',
#       'answer_start': 83}],
#     'is_impossible': False}]},
#  {'context': 'We have used the SDA Tool V8 available on Science Targets website to develop our medium term (ABS2) and long term (ABS3) SBT. The lack of methodology for setting Scope 3 targets for financial institutions has prevented us from publishing these targets. We have been in constant contact with the SBT organisation to keep up to date with the latest developments regarding a methodology for financial institutions. It is our understanding that this is at an advanced stage and we will continue to participate with this process with the ultimate goal of publishing our targets.  Note 1: Data from all our locations in ROI (AIB and EBS), UK (FTB and AIB GB), as well as our US have been considered. Note 2: Excluded from Scope 1 total, emissions of refrigerants and vehicle fleet. Note 3: After completion of a rebaseline emissions exercise in 2018, we re-ran the model (SDA Tool V8). This resulted in a slight variation of our original % SBT. The new calculated % emissions target was used when reporting ABS2 information.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'SDA Tool V8 available on Science Targets',
#       'answer_start': 17}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'Scope 3', 'answer_start': 162}],
#     'is_impossible': False}]},
#  {'context': 'Due to a proactive approach to switching to renewable electricity contracts combined with investments in solar panels in several locations, we are well underway in reaching our 2030 goals for 33% reduction of CO2 emissions from direct operations. 2017 emissions showed a 17.6% reduction compared to 2015 base year emissions, amounting to achieving 53.4% of the total 2030 reduction goal.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'renewable electricity', 'answer_start': 44}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': '33% reduction of CO2 emissions from direct operations',
#       'answer_start': 192}],
#     'is_impossible': False}]},
#  {'context': 'Environmental Management H and S improvement (Zero accident  / Injury).  Resource Efficiency Target for packaging materials recycling  rate in 2016 is 99.2%. Target for living supplies recycling rate in 2016 is 99%.  To perform audit to material suppliers in resource efficiency.                                              (Select CNC top seven material suppliers) Carbon Footprint and Ozone Depletion  Carbon dioxide emissions in 2017 decreased by 17.6% compared with the same period in 2012, a decrease of 6.5% compared with the same period in 2016 (10.4% in 2016 than in 2012) Improve the target including energy saving, water usage reduction and etc. targets include (energy savingã€\x81Water usage reduction, etc.) ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'energy saving, water usage reduction',
#       'answer_start': 611}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'packaging materials recycling  rate in 2016 is 99.2%. Target for living supplies recycling rate in 2016 is 99%',
#       'answer_start': 104}],
#     'is_impossible': False}]},
#  {'context': 'Emissions are projected based on circumstances in line with operating plans (stripping ratios, ore hardness, haul distances, expansions and closures, etc.) and then performance is measured, ex-post, in line with the World Resources Instituteâ€™s (WRI) Policy and Action Standard. Improvements are achieved by selecting and implementing high value energy efficiency and GHG mitigating and include projects undertaken through operational improvements and supply chain procurement. In 2011, we launched our operational energy- and carbon management programme,  ECO2MAN, following increased recognition of our responsibility to reduce operational GHG emissions, as well as growing concern over the potential bearing on the business of the policy responses to climate change. Through ECO2MAN, we have been able to analyse our activities and identify opportunities to reduce energy consumption and carbon emissions. This understanding formed the basis for setting our ambitious target to reduce GHG emissions by 22% against our adjusted 2020 baseline consumption (subject to divestments and significant business changes). ECO2MAN is supported by a mandatory carbon and energy technical standard and related guidance.  ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'operational energy- and carbon management programme,  ECO2MAN',
#       'answer_start': 504}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce energy consumption and carbon emissions',
#       'answer_start': 862}],
#     'is_impossible': False}]},
#  {'context': 'We currently have set a target (not science-based), to reduce greenhouse gas emissions by 2 % annually for the next 5 years. The target was set from January 2018, and progress will be measured at the end of the year. It is anticipated that the reductions would be more than 2 % for the year because one of the mines under reduced operations mode. The recorded achieved reduction of 27% does not necessarily mean that the target is exceeded, but it is partly due to reduced operations at the mine. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'reduced operations at the mine',
#       'answer_start': 465}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce greenhouse gas emissions by 2 % annually for the next 5 years',
#       'answer_start': 55}],
#     'is_impossible': False}]},
#  {'context': 'Based on the required reduction targets of SBT, based on the required reduction targets of SBT, we set the target for reduction targets for every 1.7% year by year, based on the Essential reduction targets of SBT.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'SBT', 'answer_start': 43}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduction targets for every 1.7% year by year',
#       'answer_start': 118}],
#     'is_impossible': False}]},
#  {'context': "In addition to our 2021 GHG emissions reduction goal, we are committing to achieve an 85% absolute, aggregate reduction in Scope 1 and 2 (market-based) emissions by 2040 from a 2011 base year. We considered the recommendation by the Intergovernmental Panel on Climate Change (IPCC) that global absolute emissions be reduced by 80% below 1990 levels by 2050 to avoid the most significant climate change impacts. Although CDP requirements state that a GHG emissions goal with 2.1% year on year reduction between base year and target year would be consistent with IPCC's science based recommendation, we set a more aggressive goal by committing to an 85% absolute reduction goal over twenty-nine years. To help us achieve this GHG goal, we also have an operational goal to achieve a 25% increase in energy efficiency from 2011 to 2018",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'achieve a 25% increase in energy efficiency',
#       'answer_start': 770}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'GHG emissions reduction', 'answer_start': 24}],
#     'is_impossible': False}]},
#  {'context': 'To accord with the power saving policy of Taiwanâ€™s Bureau of Energy, which specifies a reduction of overall electricity consumption by 5% from 2015 to 2020, ACC has proposed a number of energy-saving measures. In 2014, the GHG Scope 2 emission was 209,947 tons of CO2e. In 2017, the Scope 2 emission dropped to 186158 tons of CO2e.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduction of overall electricity consumption by 5% from 2015 to 2020',
#       'answer_start': 89}],
#     'is_impossible': False}]},
#  {'context': 'This target is relative to US based facilities only. It does not cover international facilities.  The emissions included 68 owned and 87 leased offices in US.  From 2016 to 2017, it showed an increase in natural gas related emissions (28%); however, electricity-related emissions decreased by 13%, gasoline-related emissions decreased 2%, and vehicle related emissions decreased by 77%.   When lease opportunities arise, ADP continues to look and enter into new leases agreements that align with green building standards (e.g.LEED).',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'LEED', 'answer_start': 526}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'ADP continues to look and enter into new leases agreements that align with green building standards (e.g.LEED)',
#       'answer_start': 421}],
#     'is_impossible': False}]},
#  {'context': 'We have exceeded our target in 2017 principally through use of more efficient use of energy across the business. 1 year ahead of the 2018 objective deadline. We have just acquired a business in the US (Ruckus) and need to understand the impact of this in relation to this objective.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'efficient use of energy across the business',
#       'answer_start': 68}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [],
#     'is_impossible': True}]},
#  {'context': 'The absolute reduction target in the medium term is primarily an energy effiency target which has been translated into tons of CO2. In fiscal year 2013 we launched our Group wide Sustainabilty Straegy, which aims to reduce CO2 emissions by 100.000 tCO2 by 2018. The program is being implemented through concrete Projects at individual sites. In line with the Vision 2025 a new CO2 reduction target 2023 will be introduced and stated in 2018.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'energy effiency', 'answer_start': 65}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce CO2 emissions by 100.000 tCO2 by 2018',
#       'answer_start': 216}],
#     'is_impossible': False}]},
#  {'context': 'Our goal is to achieve at least a 3% absolute reduction year over year. By basing our approach on The 3% Solution developed by World Wildlife Fund, CDP and McKinsey & Company, weâ€™ll cut emissions by a minimum of 26 percent over the next decade. We anticipate our science-based target to be approved by the SBTi by the end of 2018.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'science-based target', 'answer_start': 265}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'to achieve at least a 3% absolute reduction year over year',
#       'answer_start': 12}],
#     'is_impossible': False}]},
#  {'context': "The 2017 values (33'045 metric tons CO2e) represent a reduction of 36% from base year 2012 (52'372 metric tons CO2e). The slight increase year on year may be due to the fact that facilities emissions may have been challenged by high heating demand directly related to long and cold winters felt in Europe and North America.  NB: the GHG emissions from electricity were restated for 2012 and 2013, because some consumption values were overestimated in the past years. Presumably, in big markets some very energy-intensive sites (e.g. due to IT server stations) were prorated on country level. This is all within the uncertainty range of up to 40%, as always indicated in CDP reportings.",
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'CO2e', 'answer_start': 36}],
#     'is_impossible': False}]},
#  {'context': 'Our target is to reduce the carbon emissions associated with our supply chain (GHGP Corporate Value Chain (Scope 3) Accounting and Reporting Standard categories 1 through 8) by 29% by 2030 from 31 Mar 2017 outturn. ',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [],
#     'is_impossible': True},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reduce the carbon emissions associated with our supply chain (GHGP Corporate Value Chain (Scope 3) Accounting and Reporting Standard categories 1 through 8) by 29% by 2030 from 31 Mar 2017 outturn',
#       'answer_start': 17}],
#     'is_impossible': False}]},
#  {'context': 'This target of reducing 100 percent of Scope 2 emissions for all of our worldwide facilities (by powering our facilities worldwide with 100 percent renewable energy) applies to all Apple corporate facilities, data centers, and retail stores worldwide. All reductions to be achieved primarily by energy efficiency projects and new Apple-created renewable generation projects and the direct procurement of bundled renewable energy. As of the end of fiscal year 2017, we have reduced our Scope 2 market-based emissions by 74 percent compared to fiscal year 2011. Note that in fiscal year 2016, we expanded our reporting boundary of scope 2 emissions to include emissions from distribution centers and colocation facilities.  Also note that we achieved our 100 percent scope 2 emissions reduction target for all of our worldwide facilities in January 2018.',
#   'qas': [{'question': 'What is the emission reduction mechanism or technology used here? ',
#     'id': 430862,
#     'answers': [{'text': 'renewable energy', 'answer_start': 412}],
#     'is_impossible': False},
#    {'question': 'What emission reduction target is supposedly aimed?',
#     'id': 430864,
#     'answers': [{'text': 'reducing 100 percent of Scope 2 emissions for all of our worldwide facilities',
#       'answer_start': 15}],
#     'is_impossible': False}]}]

# %%
with open(r"test.json", "r") as read_file:
    test = json.load(read_file)['data']

# %%
test_squad = []
for item in train:
    for paragraph in item['paragraphs']:
        context = paragraph['context']
        qas = []
        for qa in paragraph['qas']:
            question = qa['question']
            id = qa['id']
            answers = []
            for answer in qa['answers']:
                text = answer['text']
                answer_start = answer['answer_start']
                answers.append({'text': text, 'answer_start': answer_start})
            is_impossible = qa['is_impossible']
            qas.append({'question': question, 'id': id, 'answers': answers, 'is_impossible': is_impossible})
        test_squad.append({'context': context, 'qas': qas})

# %%
import logging

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# %%
model_type="roberta"
model_name= "roberta-base"
if model_type == "bert":
    model_name = "bert-base-cased"

elif model_type == "roberta":
    model_name = "roberta-base"

elif model_type == "distilbert":
    model_name = "distilbert-base-cased"

elif model_type == "distilroberta":
    model_type = "roberta"
    model_name = "distilroberta-base"

elif model_type == "electra-base":
    model_type = "electra"
    model_name = "google/electra-base-discriminator"

elif model_type == "electra-small":
    model_type = "electra"
    model_name = "google/electra-small-discriminator"

# %%
# Configure the model 
model_args = QuestionAnsweringArgs()
model_args.train_batch_size = 32
model_args.evaluate_during_training = True
model_args.n_best_size=2
model_args.num_train_epochs=10

# %%
### Advanced Methodology
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_query_length": 64,
    "num_train_epochs": 5,
    # "evaluate_during_training_steps": 1000,
    "wandb_project": "Question Answer Application",
    "wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":2
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    # "train_batch_size": 128,
    # "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
}

# %%
model = QuestionAnsweringModel(
    model_type, model_name, args=train_args
)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForQuestionAnswering: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
### Remove output folder
# !rm -rf outputs

# %%
# Train the model
model.train_model(train_squad, eval_data=test_squad)
# Out:
# convert squad examples to features: 100%|██████████| 123/123 [00:00<00:00, 155.91it/s]
# add example index and unique id: 100%|██████████| 123/123 [00:00<00:00, 116798.59it/s]
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Finishing last run (ID:isqzdrd4) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>▁</td></tr><tr><td>correct</td><td>▁▁▁▁▁</td></tr><tr><td>eval_loss</td><td>█▃▂▁▁</td></tr><tr><td>global_step</td><td>▁▃▅▅▆█</td></tr><tr><td>incorrect</td><td>█▁▁▁▁</td></tr><tr><td>lr</td><td>▁</td></tr><tr><td>similar</td><td>▁████</td></tr><tr><td>train_loss</td><td>█▅▃▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>2.19543</td></tr><tr><td>correct</td><td>0</td></tr><tr><td>eval_loss</td><td>-4.0513</td></tr><tr><td>global_step</td><td>75</td></tr><tr><td>incorrect</td><td>1</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>similar</td><td>1</td></tr><tr><td>train_loss</td><td>2.07861</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">roberta-base</strong>: <a href="https://wandb.ai/ayush-bhosle/Question%20Answer%20Application/runs/isqzdrd4" target="_blank">https://wandb.ai/ayush-bhosle/Question%20Answer%20Application/runs/isqzdrd4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220817_120556-isqzdrd4/logs</code>
# Successfully finished last run (ID:isqzdrd4). Initializing new run:<br/>
# Tracking run with wandb version 0.13.1
# Run data is saved locally in <code>/content/wandb/run-20220817_122716-1ah75bn5</code>
# Syncing run <strong><a href="https://wandb.ai/ayush-bhosle/Question%20Answer%20Application/runs/1ah75bn5" target="_blank">roberta-base</a></strong> to <a href="https://wandb.ai/ayush-bhosle/Question%20Answer%20Application" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Running Epoch 0 of 5:   0%|          | 0/16 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/123 [00:00<?, ?it/s]
# convert squad examples to features: 100%|██████████| 123/123 [00:00<00:00, 158.64it/s]
#
# add example index and unique id: 100%|██████████| 123/123 [00:00<00:00, 279771.90it/s]
# Running Evaluation:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Epoch 1 of 5:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Epoch 2 of 5:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Epoch 3 of 5:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Epoch 4 of 5:   0%|          | 0/16 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/16 [00:00<?, ?it/s]
# (80,
#  {'global_step': [16, 32, 48, 64, 80],
#   'correct': [0, 0, 0, 0, 0],
#   'similar': [2, 2, 2, 2, 2],
#   'incorrect': [0, 0, 0, 0, 0],
#   'train_loss': [4.119726657867432,
#    2.411181688308716,
#    3.156445264816284,
#    1.832128882408142,
#    1.697509765625],
#   'eval_loss': [-0.5979461669921875,
#    -2.6019287109375,
#    -2.9969482421875,
#    -3.3046875,
#    -3.64013671875]})

# %%
# Evaluate the model
result, texts = model.eval_model(test_squad)
# Out:
# Running Evaluation:   0%|          | 0/16 [00:00<?, ?it/s]

# %%
result
# Out:
# {'correct': 0, 'similar': 2, 'incorrect': 0, 'eval_loss': -3.64013671875}

# %%
# Make predictions with the model
to_predict = [
    {
        "context": "1.We make office energy efficiency policy to reduce power consumption  2. low-carbon transportationï¼Œ slowly cut back on car usage.",
        "qas": [
            {
                "question": "What is the emission reduction mechanism or technology used here?",
                "id": "0",
            }
        ],
    }
]

# %%
answers, probabilities = model.predict(to_predict)

print(answers[0]['answer'])
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 127.30it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 624.43it/s]
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# ['reduce power consumption 2. low-carbon transportationï¼Œ slowly cut back on car usage.', 'low-carbon transportationï¼Œ slowly cut back on car usage.']

# %%
# Make predictions with the model
to_predict_ex2 = [
    {
        "context": "Our base year is 2018/19. We have used science-based target setting tools to calculate a target in line with less than 1.5 degrees of global warming (i.e. .more ambitious than the SBTi tool required for 1.5 degrees) to reduce our scope 1 + 2 emissions by 2030 by 80% using the market-based Scope 2 accounting approach. ",
        "qas": [
            {
                "question": "What is the emission reduction mechanism or technology used here?",
                "id": "1",
            }
        ],
    }
]

# %%
answers, probabilities = model.predict(to_predict_ex2)

print(answers[0]['answer'])
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 79.62it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 424.40it/s]
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# ['science-based target setting tools to calculate a target in line with less than 1.5 degrees of global warming (i.e. .more ambitious than the SBTi tool required for 1.5 degrees) to reduce our scope 1 + 2 emissions by 2030 by 80% using the market-based Scope 2 accounting approach.']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

def copytree(src, dst, symlinks=False, ignore=None):
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.exists(d):
            try:
                shutil.rmtree(d)
            except Exception as e:
                print(e)
                os.unlink(d)
        if os.path.isdir(s):
            shutil.copytree(s, d, symlinks, ignore)
        else:
            shutil.copy2(s, d)

copytree(src='/content/outputs/roberta/', dst='/content/drive/MyDrive/QNA_Run3/')
